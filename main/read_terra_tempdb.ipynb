# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

temp = pd.read_csv('/Users/nilslec/Downloads/influxdata_2024-07-28T20_45_10Z.csv',names = ['errState','relState', 'SP','device', 'temp', 'time'], header = 3, dtype = {'errState': bool, 'relState': bool, 'SP': np.float64, 'device': str, 'temp': np.float64},parse_dates=['time'])

print(temp.shape)
# Drop rows with NaN index
temp.dropna(subset=['time'], inplace=True)

# Set the 'time' column as the index
temp.set_index('time', inplace=True)

temp = temp.sort_values('time')

print(temp.shape)
# Plot the temperature over time
plt.figure(figsize=(10, 6))
plt.plot(temp.index[0:-1:1], temp['temp'][0:-1:1])
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Temperature Over Time')
plt.grid(True)
plt.show()


plt.figure(figsize=(10, 6))
plt.scatter(temp.index[0:-1:10], temp['relState'][0:-1:10])
plt.xlabel('Time')
plt.ylabel('Relay State')
plt.title('Relay State')
plt.grid(True)
plt.show()
# Out:
# (39146, 6)
# (39146, 5)
